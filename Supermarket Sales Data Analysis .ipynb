# %% [markdown]
# # Supermarket Sales Data Analysis

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_excel(r'C:\Users\user\Desktop\Data Sets\supermarket_sales.xlsx')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# # KPIs

# %% [markdown]
# #### - Count of Sales

# %%
df['Quantity'].count()
# Out:
# 1000

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#        Time      Payment    cogs  gross margin percentage  gross income  \
# 0  13:08:00      Ewallet  522.83                 4.761905       26.1415
# ...

# %% [markdown]
# #### - Total Revenue

# %%
total_revenue = df['Total'].sum()
total_revenue
# Out:
# 322966.749

# %% [markdown]
# #### - Total Cost

# %%
total_cost = df['cogs'].sum()
total_cost
# Out:
# 307587.38

# %% [markdown]
# #### - Gross Profit

# %%
Gross_profit = total_revenue - total_cost
Gross_profit
# Out:
# 15379.369000000006

# %% [markdown]
# #### - Average_rating

# %%
Average_rating = round(df['Rating'].mean(), 2)
Average_rating
# Out:
# 6.97

# %% [markdown]
# ## Trend Analysis

# %%
#df['date'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#        Time      Payment    cogs  gross margin percentage  gross income  \
# 0  13:08:00      Ewallet  522.83                 4.761905       26.1415
# ...

# %%
df['month'] = df['Date'].dt.month

# %%
df['Date'].dt.year
# Out:
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
#        ...
# 995    2019
# 996    2019
# 997    2019
# 998    2019
# 999    2019
# Name: Date, Length: 1000, dtype: int64

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#        Time      Payment    cogs  gross margin percentage  gross income  \
# 0  13:08:00      Ewallet  522.83                 4.761905       26.1415
# ...

# %%
monthly_revenue = df.groupby('month')['Total'].sum().sort_values()
monthly_revenue
# Out:
# month
# 2     97219.374
# 3    109455.507
# 1    116291.868
# Name: Total, dtype: float64

# %%
monthly_revenue.plot(x='Month', y='Total_revenue', kind='line', grid= True)
plt.show()

# %% [markdown]
# - According to the table above, it can be seen that the highest Revenue recorded in the first month.

# %%
df.groupby('Time')['Total'].max().sort_values(ascending= False)
# Out:
# Time
# 14:53:00    1042.650
# 16:20:00    1039.290
# 20:23:00    1034.460
# 16:18:00    1023.750
# 17:16:00    1022.490
#               ...
# 15:09:00      26.250
# 20:47:00      24.108
# 15:23:00      16.275
# 11:09:00      16.107
# 14:11:00      13.419
# Name: Total, Length: 506, dtype: float64

# %%
df.groupby('Time')['Total'].max().sort_values(ascending= False).plot(figsize= (12,4), marker= '.',grid= True)
# Out:
# <AxesSubplot:xlabel='Time'>

# %% [markdown]
# - Sales can in other words be termed as sales therefore the maximum 'Total'(revenue) was used and it can be seen above
#   that highest sales(revenue) was recorded at 14:53:00

# %% [markdown]
# ## Revenue analysis

# %%
df.groupby('Branch')['Total'].sum().sort_values(ascending= False)
# Out:
# Branch
# C    110568.7065
# A    106200.3705
# B    106197.6720
# Name: Total, dtype: float64

# %%
ax = df.groupby('Branch')['Total'].sum().sort_values(ascending= False).plot(kind='bar',figsize=(7,4),title='Total Sales By Branch',grid= True)

ax.set_xlabel('Branch')
ax.set_ylabel('Total Sales')

plt.show()

# %% [markdown]
# - Branch 'C' recorded the highest revenue followed by Branch 'A' and the Branch 'B'

# %%
df.groupby('Customer type')['Total'].sum().sort_values(ascending=False)
# Out:
# Customer type
# Member    164223.444
# Normal    158743.305
# Name: Total, dtype: float64

# %%
df.groupby('Customer type')['Total'].sum().sort_values(ascending=False).plot(kind='bar')
plt.xlabel('Customer Type')
plt.ylabel('Total Sales')
plt.title('Total Sales By Customer Type')
plt.show()

# %% [markdown]
# - Customer type 'Member' recorded the highest revenue as compared to Customer type 'Normal'

# %%
df.groupby('Gender')['Total'].sum().sort_values(ascending=False)
# Out:
# Gender
# Female    167882.925
# Male      155083.824
# Name: Total, dtype: float64

# %%
df.groupby('Gender')['Total'].sum().sort_values(ascending=False).plot(kind= 'bar')
# Out:
# <AxesSubplot:xlabel='Gender'>

# %% [markdown]
# - Females contributed the highest revenue as compared to Males

# %%
df.groupby('Product line')['Total'].sum().sort_values(ascending=False)
# Out:
# Product line
# Food and beverages        56144.8440
# Sports and travel         55122.8265
# Electronic accessories    54337.5315
# Fashion accessories       54305.8950
# Home and lifestyle        53861.9130
# Health and beauty         49193.7390
# Name: Total, dtype: float64

# %%
df.groupby('Product line')['Total'].sum().sort_values(ascending=False).plot(kind='bar', grid=True)
plt.title('Product line Total Sales')
plt.xlabel('Product line')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# - Food and beverages formed the highest revenue in terms of Product line

# %%
df.groupby('Payment')['Total'].sum().sort_values(ascending=False)
# Out:
# Payment
# Cash           112206.570
# Ewallet        109993.107
# Credit card    100767.072
# Name: Total, dtype: float64

# %%
df.groupby('Payment')['Total'].sum().sort_values(ascending=False).plot.bar(color='green', figsize=(8,5))
plt.title('Total Sales by Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# - Most people prefered to pay in cash followed by Ewallet and then Credit card

# %% [markdown]
# ## Cost Analysis

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#        Time      Payment    cogs  gross margin percentage  gross income  \
# 0  13:08:00      Ewallet  522.83                 4.761905       26.1415
# ...

# %%
df.groupby('Product line')['cogs'].sum()
# Out:
# Product line
# Electronic accessories    51750.03
# Fashion accessories       51719.90
# Food and beverages        53471.28
# Health and beauty         46851.18
# Home and lifestyle        51297.06
# Sports and travel         52497.93
# Name: cogs, dtype: float64

# %%
df.groupby('Product line')['cogs'].sum().plot(kind= 'bar')
# Out:
# <AxesSubplot:xlabel='Product line'>

# %% [markdown]
# - The company incured most of its cost on Electronic accessories

# %%
df.groupby('Branch')['cogs'].sum().sort_values(ascending= False)
# Out:
# Branch
# C    105303.53
# A    101143.21
# B    101140.64
# Name: cogs, dtype: float64

# %%
df.groupby('Branch')['cogs'].sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Branch'>

# %% [markdown]
# - The company incured more cost Branch 'C', followed by Branch 'A'  and Branch 'B'

# %% [markdown]
# ## Rating Analysis

# %%
df.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
#
#        Time  Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08:00  Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29:00     Cash   76.40                 4.761905        3.8200     9.6
#
#    month
# 0      1
# 1      3

# %%
df.groupby('Payment')['Rating'].max().sort_values(ascending= False)
# Out:
# Payment
# Credit card    10.0
# Ewallet        10.0
# Cash            9.9
# Name: Rating, dtype: float64

# %%
df.groupby('Payment')['Rating'].max().sort_values(ascending= False).plot(kind= 'bar')
# Out:
# <AxesSubplot:xlabel='Payment'>

# %% [markdown]
# - Credit card and Ewallet had the highest ratings of 10
#   However, there was a very slim difference between them and that of caash

# %% [markdown]
# ## Relationship Analysis

# %%
df['Unit price'].corr(df['Quantity']).round(3)
# Out:
# 0.011

# %% [markdown]
# - From the above correllation values, it can be seen that there is zero correlation between Unit price and Quantity
#   In other words the there is no visible relationship between them.

# %%
df['cogs'].corr(df['Total']).round(3)
# Out:
# 1.0

# %% [markdown]
# - From the above correllation values, it can be seen that there is a perfect correlation between Cost of goods and Revenue
#   This implies as the revenue goes up, the cost also goes up.

# %%
df['Rating'].corr(df['Unit price']).round(3)
# Out:
# -0.009

# %% [markdown]
# - From the above correllation values, it can be seen that there is zero correlation between Unit Ratings and Unit price
#   In other words the there is no visible relationship between them.
